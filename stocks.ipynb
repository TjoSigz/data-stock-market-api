# %% [markdown]
# **Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Make call to URL**

# %%
import requests

url = "https://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data = requests.get(url).json()

# %% [markdown]
# **Create apple_df DataFrame**

# %%
apple_df=pd.DataFrame(api_data)
apple_df.head(4)
# Out:
#     close     high      low    open   priceDate symbol    volume  \
# 0  191.45  191.905  189.880  189.89  2023-11-20   AAPL  46538614
# 1  190.64  191.520  189.740  191.41  2023-11-21   AAPL  38134485
# 2  191.31  192.930  190.825  191.49  2023-11-22   AAPL  39630011
# 3  189.97  190.900  189.250  190.87  2023-11-24   AAPL  24048344
#
#                   id   key subkey  ...     uLow   uVolume   fOpen  fClose  \
# 0  HISTORICAL_PRICES  AAPL         ...  189.880  46538614  189.89  191.45
# 1  HISTORICAL_PRICES  AAPL         ...  189.740  38134485  191.41  190.64
# 2  HISTORICAL_PRICES  AAPL         ...  190.825  39630011  191.49  191.31
# 3  HISTORICAL_PRICES  AAPL         ...  189.250  24048344  190.87  189.97
#
#      fHigh     fLow   fVolume       label  change  changePercent
# 0  191.905  189.880  46538614  Nov 20, 23    0.00         0.0000
# 1  191.520  189.740  38134485  Nov 21, 23   -0.81        -0.0042
# 2  192.930  190.825  39630011  Nov 22, 23    0.67         0.0035
# ...

# %% [markdown]
# **Convert the date to a datetime object**

# %%
apple_df['priceDate'] = pd.to_datetime(apple_df['priceDate'],format="%Y-%m-%d")
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   close                 61 non-null     float64
#  1   high                  61 non-null     float64
#  2   low                   61 non-null     float64
#  3   open                  61 non-null     float64
#  4   priceDate             61 non-null     datetime64[ns]
#  5   symbol                61 non-null     object
#  6   volume                61 non-null     int64
#  7   id                    61 non-null     object
#  8   key                   61 non-null     object
#  9   subkey                61 non-null     object
#  10  date                  61 non-null     datetime64[ns]
#  11  updated               61 non-null     int64
#  12  changeOverTime        61 non-null     float64
#  13  marketChangeOverTime  61 non-null     float64
# ...

# %% [markdown]
# **Set the date column as the index**

# %%
#apple_df = apple_df.set_index('date')
apple_df.head(5)
# Out:
#              close     high      low    open  priceDate symbol    volume  \
# date
# 2023-11-20  191.45  191.905  189.880  189.89 2023-11-20   AAPL  46538614
# 2023-11-21  190.64  191.520  189.740  191.41 2023-11-21   AAPL  38134485
# 2023-11-22  191.31  192.930  190.825  191.49 2023-11-22   AAPL  39630011
# 2023-11-24  189.97  190.900  189.250  190.87 2023-11-24   AAPL  24048344
# 2023-11-27  189.79  190.670  188.900  189.92 2023-11-27   AAPL  40552609
#
#                            id   key subkey  ...     uLow   uVolume   fOpen  \
# date                                        ...
# 2023-11-20  HISTORICAL_PRICES  AAPL         ...  189.880  46538614  189.89
# 2023-11-21  HISTORICAL_PRICES  AAPL         ...  189.740  38134485  191.41
# 2023-11-22  HISTORICAL_PRICES  AAPL         ...  190.825  39630011  191.49
# 2023-11-24  HISTORICAL_PRICES  AAPL         ...  189.250  24048344  190.87
# 2023-11-27  HISTORICAL_PRICES  AAPL         ...  188.900  40552609  189.92
#
# ...

# %% [markdown]
# ***Plot with only the values in the close column**

# %%
close_df = apple_df['close']
close_df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **Plot with the values in the open, close, high, and low columns**

# %%
apple_df[['open', 'close', 'high', 'low']].plot(figsize= (12,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# **Test your code!**

# %%
from nbresult import ChallengeResult

result = ChallengeResult('apple',
    index_name=apple_df.index.name,
    index_type=apple_df.index.dtype,
    columns=apple_df.columns
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/tawsig/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/tawsig/code/TjoSigz/02-Data-Toolkit/02-Data-Sourcing/data-stock-market-api/tests
# plugins: anyio-3.6.2, asyncio-0.19.0
# asyncio: mode=strict
# collecting ... collected 3 items
#
# test_apple.py::TestApple::test_apple_df_columns PASSED                   [ 33%]
# test_apple.py::TestApple::test_apple_df_index_is_timestamp PASSED        [ 66%]
# test_apple.py::TestApple::test_apple_df_index_name_is_date PASSED        [100%]
#
# ============================== 3 passed in 1.40s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/apple.pickle
#
# git commit -m 'Completed apple step'
#
# git push origin master
